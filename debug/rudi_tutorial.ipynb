# %% [markdown]
# # Rudimentary use of gap_fit and quip to check for possible dissonance - Water

# %%
# general imports
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy as cp

# ase imports
import ase.io
from ase import Atoms, Atom
from ase import units
from ase.build import molecule
# for MD
from ase.md.langevin import Langevin
from ase.io.trajectory import Trajectory

# %%
# helper functions
def make_water(density, super_cell=[3, 3, 3]):
    """ Geenrates a supercell of water molecules with a desired density.
        Density in g/cm^3!!!"""
    h2o = molecule('H2O')
    a = np.cbrt((sum(h2o.get_masses()) * units.m ** 3 * 1E-6 ) / (density * units.mol))
    h2o.set_cell((a, a, a))
    h2o.set_pbc((True, True, True))
    #return cp(h2o.repeat(super_cell))
    return h2o.repeat(super_cell)

def rms_dict(x_ref, x_pred):
    """ Takes two datasets of the same shape and returns a dictionary containing RMS error data"""

    x_ref = np.array(x_ref)
    x_pred = np.array(x_pred)

    if np.shape(x_pred) != np.shape(x_ref):
        raise ValueError('WARNING: not matching shapes in rms')

    error_2 = (x_ref - x_pred) ** 2

    average = np.sqrt(np.average(error_2))
    std_ = np.sqrt(np.var(error_2))

    return {'rmse': average, 'std': std_}

# %%
from ase.calculators.emt import EMT
calc = EMT()

T = 150  # Kelvin

# Set up a grid of water
water = make_water(1.0, [3, 3, 3])
water.set_calculator(calc)

# We want to run MD using the Langevin algorithm
# with a time step of 1 fs, the temperature T and the friction
# coefficient to 0.002 atomic units.
dyn = Langevin(water, 1 * units.fs, T * units.kB, 0.0002)

def printenergy(a=water):  # store a reference to atoms in the definition.
    """Function to print the potential, kinetic and total energy."""
    epot = a.get_potential_energy() / len(a)
    ekin = a.get_kinetic_energy() / len(a)
    print('Energy per atom: Epot = %.3feV  Ekin = %.3feV (T=%3.0fK)  '
          'Etot = %.3feV' % (epot, ekin, ekin / (1.5 * units.kB), epot + ekin))

dyn.attach(printenergy, interval=5)

# We also want to save the positions of all atoms after every 5th time step.
traj = Trajectory('dyn_emt.traj', 'w', water)
dyn.attach(traj.write, interval=5)

# Now run the dynamics
printenergy(water)
dyn.run(600)   # CHANGE THIS IF YOU WANT LONGER/SHORTER RUN
# Out:
# Energy per atom: Epot = 0.885eV  Ekin = 0.000eV (T=  0K)  Etot = 0.885eV
# Energy per atom: Epot = 0.885eV  Ekin = 0.000eV (T=  0K)  Etot = 0.885eV
# Energy per atom: Epot = 0.820eV  Ekin = 0.053eV (T=414K)  Etot = 0.874eV
# Energy per atom: Epot = 0.660eV  Ekin = 0.208eV (T=1610K)  Etot = 0.868eV
# Energy per atom: Epot = 0.633eV  Ekin = 0.224eV (T=1734K)  Etot = 0.857eV
# Energy per atom: Epot = 0.869eV  Ekin = 0.005eV (T= 39K)  Etot = 0.874eV
# Energy per atom: Epot = 0.780eV  Ekin = 0.089eV (T=687K)  Etot = 0.869eV
# Energy per atom: Epot = 0.755eV  Ekin = 0.117eV (T=906K)  Etot = 0.873eV
# Energy per atom: Epot = 0.706eV  Ekin = 0.164eV (T=1271K)  Etot = 0.870eV
# Energy per atom: Epot = 0.703eV  Ekin = 0.158eV (T=1224K)  Etot = 0.861eV
# Energy per atom: Epot = 0.868eV  Ekin = 0.006eV (T= 44K)  Etot = 0.874eV
# Energy per atom: Epot = 0.696eV  Ekin = 0.167eV (T=1295K)  Etot = 0.864eV
# Energy per atom: Epot = 0.678eV  Ekin = 0.190eV (T=1471K)  Etot = 0.868eV
# Energy per atom: Epot = 0.823eV  Ekin = 0.050eV (T=383K)  Etot = 0.872eV
# Energy per atom: Epot = 0.771eV  Ekin = 0.098eV (T=758K)  Etot = 0.869eV
# Energy per atom: Epot = 0.781eV  Ekin = 0.090eV (T=698K)  Etot = 0.871eV
# Energy per atom: Epot = 0.724eV  Ekin = 0.144eV (T=1116K)  Etot = 0.868eV
# Energy per atom: Epot = 0.728eV  Ekin = 0.140eV (T=1083K)  Etot = 0.868eV
# Energy per atom: Epot = 0.766eV  Ekin = 0.105eV (T=816K)  Etot = 0.871eV
# Energy per atom: Epot = 0.752eV  Ekin = 0.118eV (T=910K)  Etot = 0.870eV
# Energy per atom: Epot = 0.770eV  Ekin = 0.102eV (T=787K)  Etot = 0.872eV
# Energy per atom: Epot = 0.740eV  Ekin = 0.131eV (T=1014K)  Etot = 0.871eV
# Energy per atom: Epot = 0.720eV  Ekin = 0.150eV (T=1162K)  Etot = 0.870eV
# Energy per atom: Epot = 0.724eV  Ekin = 0.147eV (T=1133K)  Etot = 0.870eV
# Energy per atom: Epot = 0.724eV  Ekin = 0.147eV (T=1136K)  Etot = 0.870eV
# Energy per atom: Epot = 0.718eV  Ekin = 0.153eV (T=1186K)  Etot = 0.871eV
# Energy per atom: Epot = 0.717eV  Ekin = 0.153eV (T=1184K)  Etot = 0.870eV
# Energy per atom: Epot = 0.721eV  Ekin = 0.150eV (T=1164K)  Etot = 0.871eV
# Energy per atom: Epot = 0.716eV  Ekin = 0.155eV (T=1199K)  Etot = 0.871eV
# Energy per atom: Epot = 0.713eV  Ekin = 0.157eV (T=1216K)  Etot = 0.870eV
# Energy per atom: Epot = 0.690eV  Ekin = 0.180eV (T=1393K)  Etot = 0.870eV
# Energy per atom: Epot = 0.701eV  Ekin = 0.169eV (T=1306K)  Etot = 0.870eV
# Energy per atom: Epot = 0.687eV  Ekin = 0.184eV (T=1423K)  Etot = 0.871eV
# Energy per atom: Epot = 0.656eV  Ekin = 0.215eV (T=1662K)  Etot = 0.871eV
# Energy per atom: Epot = 0.647eV  Ekin = 0.223eV (T=1722K)  Etot = 0.870eV
# Energy per atom: Epot = 0.623eV  Ekin = 0.247eV (T=1908K)  Etot = 0.870eV
# Energy per atom: Epot = 0.578eV  Ekin = 0.292eV (T=2262K)  Etot = 0.870eV
# Energy per atom: Epot = 0.607eV  Ekin = 0.263eV (T=2033K)  Etot = 0.870eV
# Energy per atom: Epot = 0.660eV  Ekin = 0.210eV (T=1627K)  Etot = 0.870eV
# Energy per atom: Epot = 0.604eV  Ekin = 0.265eV (T=2053K)  Etot = 0.869eV
# Energy per atom: Epot = 0.613eV  Ekin = 0.257eV (T=1986K)  Etot = 0.870eV
# Energy per atom: Epot = 0.651eV  Ekin = 0.220eV (T=1700K)  Etot = 0.871eV
# Energy per atom: Epot = 0.632eV  Ekin = 0.238eV (T=1842K)  Etot = 0.870eV
# Energy per atom: Epot = 0.615eV  Ekin = 0.255eV (T=1970K)  Etot = 0.869eV
# Energy per atom: Epot = 0.585eV  Ekin = 0.284eV (T=2197K)  Etot = 0.869eV
# Energy per atom: Epot = 0.531eV  Ekin = 0.338eV (T=2613K)  Etot = 0.869eV
# Energy per atom: Epot = 0.529eV  Ekin = 0.340eV (T=2629K)  Etot = 0.869eV
# Energy per atom: Epot = 0.472eV  Ekin = 0.397eV (T=3073K)  Etot = 0.869eV
# Energy per atom: Epot = 0.514eV  Ekin = 0.356eV (T=2756K)  Etot = 0.870eV
# Energy per atom: Epot = 0.447eV  Ekin = 0.421eV (T=3255K)  Etot = 0.868eV
# Energy per atom: Epot = 0.489eV  Ekin = 0.380eV (T=2943K)  Etot = 0.869eV
# Energy per atom: Epot = 0.461eV  Ekin = 0.407eV (T=3151K)  Etot = 0.868eV
# Energy per atom: Epot = 0.499eV  Ekin = 0.371eV (T=2870K)  Etot = 0.870eV
# Energy per atom: Epot = 0.495eV  Ekin = 0.374eV (T=2897K)  Etot = 0.869eV
# Energy per atom: Epot = 0.476eV  Ekin = 0.393eV (T=3041K)  Etot = 0.869eV
# Energy per atom: Epot = 0.457eV  Ekin = 0.412eV (T=3190K)  Etot = 0.870eV
# Energy per atom: Epot = 0.440eV  Ekin = 0.428eV (T=3314K)  Etot = 0.868eV
# Energy per atom: Epot = 0.468eV  Ekin = 0.400eV (T=3095K)  Etot = 0.868eV
# Energy per atom: Epot = 0.447eV  Ekin = 0.422eV (T=3268K)  Etot = 0.869eV
# Energy per atom: Epot = 0.439eV  Ekin = 0.430eV (T=3324K)  Etot = 0.869eV
# Energy per atom: Epot = 0.466eV  Ekin = 0.409eV (T=3161K)  Etot = 0.875eV
# Energy per atom: Epot = 0.499eV  Ekin = 0.376eV (T=2906K)  Etot = 0.875eV
# Energy per atom: Epot = 0.459eV  Ekin = 0.415eV (T=3207K)  Etot = 0.874eV
# Energy per atom: Epot = 0.476eV  Ekin = 0.398eV (T=3082K)  Etot = 0.875eV
# Energy per atom: Epot = 0.444eV  Ekin = 0.429eV (T=3319K)  Etot = 0.873eV
# Energy per atom: Epot = 0.384eV  Ekin = 0.488eV (T=3779K)  Etot = 0.872eV
# Energy per atom: Epot = 0.395eV  Ekin = 0.479eV (T=3709K)  Etot = 0.874eV
# Energy per atom: Epot = 0.369eV  Ekin = 0.501eV (T=3880K)  Etot = 0.870eV
# Energy per atom: Epot = 0.388eV  Ekin = 0.483eV (T=3734K)  Etot = 0.871eV
# Energy per atom: Epot = 0.390eV  Ekin = 0.481eV (T=3725K)  Etot = 0.871eV
# Energy per atom: Epot = 0.357eV  Ekin = 0.514eV (T=3976K)  Etot = 0.871eV
# Energy per atom: Epot = 0.411eV  Ekin = 0.461eV (T=3568K)  Etot = 0.872eV
# Energy per atom: Epot = 0.425eV  Ekin = 0.448eV (T=3470K)  Etot = 0.873eV
# Energy per atom: Epot = 0.414eV  Ekin = 0.459eV (T=3547K)  Etot = 0.872eV
# Energy per atom: Epot = 0.393eV  Ekin = 0.478eV (T=3696K)  Etot = 0.871eV
# Energy per atom: Epot = 0.411eV  Ekin = 0.461eV (T=3564K)  Etot = 0.871eV
# Energy per atom: Epot = 0.409eV  Ekin = 0.463eV (T=3581K)  Etot = 0.872eV
# Energy per atom: Epot = 0.376eV  Ekin = 0.495eV (T=3828K)  Etot = 0.870eV
# Energy per atom: Epot = 0.411eV  Ekin = 0.460eV (T=3558K)  Etot = 0.871eV
# Energy per atom: Epot = 0.414eV  Ekin = 0.464eV (T=3586K)  Etot = 0.878eV
# Energy per atom: Epot = 0.420eV  Ekin = 0.465eV (T=3594K)  Etot = 0.884eV
# Energy per atom: Epot = 0.423eV  Ekin = 0.449eV (T=3476K)  Etot = 0.872eV
# Energy per atom: Epot = 0.441eV  Ekin = 0.447eV (T=3462K)  Etot = 0.889eV
# Energy per atom: Epot = 0.449eV  Ekin = 0.439eV (T=3397K)  Etot = 0.888eV
# Energy per atom: Epot = 0.467eV  Ekin = 0.422eV (T=3264K)  Etot = 0.889eV
# Energy per atom: Epot = 0.389eV  Ekin = 0.498eV (T=3849K)  Etot = 0.886eV
# Energy per atom: Epot = 0.388eV  Ekin = 0.501eV (T=3873K)  Etot = 0.889eV
# Energy per atom: Epot = 0.389eV  Ekin = 0.500eV (T=3869K)  Etot = 0.889eV
# Energy per atom: Epot = 0.414eV  Ekin = 0.472eV (T=3652K)  Etot = 0.886eV
# Energy per atom: Epot = 0.414eV  Ekin = 0.477eV (T=3691K)  Etot = 0.891eV
# Energy per atom: Epot = 0.412eV  Ekin = 0.482eV (T=3726K)  Etot = 0.894eV
# Energy per atom: Epot = 0.399eV  Ekin = 0.495eV (T=3833K)  Etot = 0.894eV
# Energy per atom: Epot = 0.387eV  Ekin = 0.506eV (T=3914K)  Etot = 0.892eV
# Energy per atom: Epot = 0.423eV  Ekin = 0.498eV (T=3850K)  Etot = 0.921eV
# Energy per atom: Epot = 0.419eV  Ekin = 0.497eV (T=3844K)  Etot = 0.916eV
# Energy per atom: Epot = 0.384eV  Ekin = 0.532eV (T=4115K)  Etot = 0.916eV
# Energy per atom: Epot = 0.400eV  Ekin = 0.516eV (T=3992K)  Etot = 0.916eV
# Energy per atom: Epot = 0.368eV  Ekin = 0.547eV (T=4231K)  Etot = 0.915eV
# Energy per atom: Epot = 0.392eV  Ekin = 0.527eV (T=4080K)  Etot = 0.919eV
# Energy per atom: Epot = 0.369eV  Ekin = 0.542eV (T=4193K)  Etot = 0.911eV
# Energy per atom: Epot = 0.363eV  Ekin = 0.567eV (T=4383K)  Etot = 0.930eV
# Energy per atom: Epot = 0.407eV  Ekin = 0.522eV (T=4039K)  Etot = 0.929eV
# Energy per atom: Epot = 0.384eV  Ekin = 0.548eV (T=4236K)  Etot = 0.931eV
# Energy per atom: Epot = 0.369eV  Ekin = 0.559eV (T=4327K)  Etot = 0.929eV
# Energy per atom: Epot = 0.377eV  Ekin = 0.553eV (T=4279K)  Etot = 0.930eV
# Energy per atom: Epot = 0.400eV  Ekin = 0.530eV (T=4101K)  Etot = 0.930eV
# Energy per atom: Epot = 0.414eV  Ekin = 0.517eV (T=4000K)  Etot = 0.931eV
# Energy per atom: Epot = 0.391eV  Ekin = 0.542eV (T=4196K)  Etot = 0.934eV
# Energy per atom: Epot = 0.363eV  Ekin = 0.568eV (T=4398K)  Etot = 0.932eV
# Energy per atom: Epot = 0.406eV  Ekin = 0.526eV (T=4069K)  Etot = 0.932eV
# Energy per atom: Epot = 0.397eV  Ekin = 0.538eV (T=4164K)  Etot = 0.935eV
# Energy per atom: Epot = 0.396eV  Ekin = 0.548eV (T=4241K)  Etot = 0.945eV
# Energy per atom: Epot = 0.439eV  Ekin = 0.507eV (T=3924K)  Etot = 0.946eV
# Energy per atom: Epot = 0.432eV  Ekin = 0.514eV (T=3973K)  Etot = 0.946eV
# Energy per atom: Epot = 0.438eV  Ekin = 0.508eV (T=3933K)  Etot = 0.946eV
# Energy per atom: Epot = 0.425eV  Ekin = 0.522eV (T=4038K)  Etot = 0.947eV
# Energy per atom: Epot = 0.435eV  Ekin = 0.515eV (T=3984K)  Etot = 0.949eV
# Energy per atom: Epot = 0.405eV  Ekin = 0.543eV (T=4203K)  Etot = 0.948eV
# Energy per atom: Epot = 0.395eV  Ekin = 0.556eV (T=4301K)  Etot = 0.951eV
# Energy per atom: Epot = 0.402eV  Ekin = 0.545eV (T=4214K)  Etot = 0.946eV
# Energy per atom: Epot = 0.403eV  Ekin = 0.542eV (T=4192K)  Etot = 0.945eV
# Energy per atom: Epot = 0.376eV  Ekin = 0.575eV (T=4448K)  Etot = 0.951eV
# True

# %%
out_traj = ase.io.read('dyn_emt.traj', ':')
for at in out_traj:
    at.wrap()
    if 'momenta' in at.arrays: del at.arrays['momenta']
ase.io.write('dyn_emt.xyz', out_traj, 'xyz')

# %%
isolated_H = Atoms('H', calculator=EMT(), cell=[20, 20, 20], pbc=True)
isolated_O = Atoms('O', calculator=EMT(), cell=[20, 20, 20], pbc=True)

print('e0_H:',isolated_H.get_potential_energy())
print('e0_O:',isolated_O.get_potential_energy())

# this made the e0 string be the following: e0={H:3.21:O:4.6}
# Out:
# e0_H: 3.21
# e0_O: 4.6

# %%
ase.io.write('train.xyz', out_traj[0::2] + [isolated_H] + [isolated_O])
ase.io.write('validate.xyz', out_traj[1::2])

# %%
! gap_fit energy_parameter_name=energy force_parameter_name=forces do_copy_at_file=F sparse_separate_file=T gp_file=GAP.xml at_file=train.xyz default_sigma={0.008 0.04 0 0} gap={distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform add_species=T n_sparse=10}
# Out:
# libAtoms::Hello World: 17/03/2021   10:24:19
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP.git,357e28d15-dirty
# libAtoms::Hello World: QUIP_ARCH    darwin_x86_64_gfortran
# libAtoms::Hello World: compiled on  Jan 15 2021 at 14:52:24
# libAtoms::Hello World: Random Seed = 37459120
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# atoms_filename = //MANDATORY//
# at_file = train.xyz
# gap = "distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform add_species=T n_sparse=10"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.008 0.04 0 0"
# sparse_jitter = 1.0e-10
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = F
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap_new.xml
# gp_file = GAP.xml
# verbosity = NORMAL
# rnd_seed = -1
# openmp_chunk_size = 1
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform add_species=T n_sparse=10}
# New GAP: {distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=8 Z2=8}
# New GAP: {distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=8 Z2=1}
# New GAP: {distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=1 Z2=1}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor: distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=8 Z2=8
# Number of descriptors:                        12630
# Number of partial derivatives of descriptors: 75780
# ---------------------------------------------------------------------
# Descriptor: distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=8 Z2=1
# Number of descriptors:                        62562
# Number of partial derivatives of descriptors: 375372
# ---------------------------------------------------------------------
# Descriptor: distance_2b cutoff=4.0 covariance_type=ard_se delta=0.5 theta_uniform=1.0 sparse_method=uniform               n_sparse=10 Z1=1 Z2=1
# Number of descriptors:                        57624
# Number of partial derivatives of descriptors: 345744
#
# ========================================  ======================================
#
# E0/atom =   0.32100000000000000E+001  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.45999999999999996E+001  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000  0.00000000000000000E+000
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 63
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 14829
# Number of target virials (property name: virial) found: 0
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in .14979800000000010 cpu secs, .18405103683471680 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in .14983099999999994 cpu secs, .18408393859863281 wall clock secs.
# Started sparse covariance matrix calculation of coordinate 2
# Finished sparse covariance matrix calculation of coordinate 2
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate2_sparse  done in .76277099999999987 cpu secs, .89938092231750488 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate2         done in .76279699999999995 cpu secs, .89940476417541504 wall clock secs.
# Started sparse covariance matrix calculation of coordinate 3
#
# Finished sparse covariance matrix calculation of coordinate 3
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate3_sparse  done in .61285899999999982 cpu secs, .63398098945617676 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate3         done in .61288900000000024 cpu secs, .63401007652282715 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_LinearAlgebra       done in .13025999999999982E-001 cpu secs, .80299377441406250E-002 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .32000000000032003E-004 cpu secs, .20980834960937500E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 1.5424269999999998 cpu secs, 1.7299797534942627 wall clock secs.
# TIMER: GP sparsify                                        done in 1.5648350000000002 cpu secs, 1.7676618099212646 wall clock secs.
#
# libAtoms::Finalise: 17/03/2021   10:24:22
# libAtoms::Finalise: Bye-Bye!

# %%
# calculate train.xyz

! quip E=T F=T atoms_filename=train.xyz param_filename=GAP.xml | grep AT | sed 's/AT//' > quip_train.xyz
! quip E=T F=T atoms_filename=validate.xyz param_filename=GAP.xml | grep AT | sed 's/AT//' > quip_validate.xyz

# %%
def energy_plot(in_file, out_file, ax, title='Plot of energy'):
    """ Plots the distribution of energy per atom on the output vs the input"""
    # read files
    in_atoms = ase.io.read(in_file, ':')
    out_atoms = ase.io.read(out_file, ':')
    # list energies
    ener_in = [at.get_potential_energy() / len(at.get_chemical_symbols()) for at in in_atoms]
    ener_out = [at.get_potential_energy() / len(at.get_chemical_symbols()) for at in out_atoms]
    # scatter plot of the data
    ax.scatter(ener_in, ener_out)
    # get the appropriate limits for the plot
    for_limits = np.array(ener_in +ener_out)
    elim = (for_limits.min() - 0.05, for_limits.max() + 0.05)
    ax.set_xlim(elim)
    ax.set_ylim(elim)
    # add line of slope 1 for refrence
    ax.plot(elim, elim, c='k')
    # set labels
    ax.set_ylabel('energy by GAP / eV')
    ax.set_xlabel('energy by EMT / eV')
    #set title
    ax.set_title(title)
    # add text about RMSE
    _rms = rms_dict(ener_in, ener_out)
    rmse_text = 'RMSE:\n' + str(np.round(_rms['rmse'], 3)) + ' +- ' + str(np.round(_rms['std'], 3)) + 'eV/atom'
    ax.text(0.9, 0.1, rmse_text, transform=ax.transAxes, fontsize='large', horizontalalignment='right',
            verticalalignment='bottom')

def force_plot(in_file, out_file, ax, symbol='HO', title='Plot of force'):
    """ Plots the distribution of firce components per atom on the output vs the input
        only plots for the given atom type(s)"""

    in_atoms = ase.io.read(in_file, ':')
    out_atoms = ase.io.read(out_file, ':')

    # extract data for only one species
    in_force, out_force = [], []
    for at_in, at_out in zip(in_atoms, out_atoms):
        # get the symbols
        sym_all = at_in.get_chemical_symbols()
        # add force for each atom
        for j, sym in enumerate(sym_all):
            if sym in symbol:
                in_force.append(at_in.get_forces()[j])
                #out_force.append(at_out.get_forces()[j]) \
                out_force.append(at_out.arrays['force'][j]) # because QUIP and ASE use different names
    # convert to np arrays, much easier to work with
    #in_force = np.array(in_force)
    #out_force = np.array(out_force)
    # scatter plot of the data
    ax.scatter(in_force, out_force)
    # get the appropriate limits for the plot
    for_limits = np.array(in_force + out_force)
    flim = (for_limits.min() - 1, for_limits.max() + 1)
    ax.set_xlim(flim)
    ax.set_ylim(flim)
    # add line of
    ax.plot(flim, flim, c='k')
    # set labels
    ax.set_ylabel('force by GAP / (eV/Å)')
    ax.set_xlabel('force by EMT / (eV/Å)')
    #set title
    ax.set_title(title)
    # add text about RMSE
    _rms = rms_dict(in_force, out_force)
    rmse_text = 'RMSE:\n' + str(np.round(_rms['rmse'], 3)) + ' +- ' + str(np.round(_rms['std'], 3)) + 'eV/Å'
    ax.text(0.9, 0.1, rmse_text, transform=ax.transAxes, fontsize='large', horizontalalignment='right',
            verticalalignment='bottom')

# %%
fig, ax_list = plt.subplots(nrows=3, ncols=2, gridspec_kw={'hspace': 0.3})
fig.set_size_inches(15, 20)
ax_list = ax_list.flat[:]

energy_plot('train.xyz', 'quip_train.xyz', ax_list[0], 'Energy on training data')
energy_plot('validate.xyz', 'quip_validate.xyz', ax_list[1], 'Energy on validation data')
force_plot('train.xyz', 'quip_train.xyz', ax_list[2], 'H', 'Force on training data - H')
force_plot('train.xyz', 'quip_train.xyz', ax_list[3], 'O', 'Force on training data - O')
force_plot('validate.xyz', 'quip_validate.xyz', ax_list[4], 'H', 'Force on validation data - H')
force_plot('validate.xyz', 'quip_validate.xyz', ax_list[5], 'O',  'Force on validation data - O')

# if you wanted to have the same limits on the force plots
#for ax in ax_list[2:]:
#    flim = (-20, 20)
#    ax.set_xlim(flim)
#    ax.set_ylim(flim)
